# %% [markdown]
# # 03 — Análisis Descriptivo
#
# **Objetivo:** Estadísticas básicas, distribuciones, correlaciones y análisis temporal de los datos procesados.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

sns.set_theme(style='whitegrid')
PROC = Path('../data/processed')
FIGS = Path('../reports/figures')
FIGS.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 1. Estadísticas descriptivas

# %%
# df = pd.read_csv(PROC / 'ml_features_clean.csv')
# df.describe().T.style.background_gradient(cmap='YlOrRd')
pass

# %% [markdown]
# ## 2. Mapa de correlaciones

# %%
# numeric = df.select_dtypes(include='number')
# fig, ax = plt.subplots(figsize=(12, 10))
# sns.heatmap(numeric.corr(), annot=True, fmt='.2f', cmap='coolwarm', ax=ax)
# ax.set_title('Mapa de correlaciones — features TEYVA')
# plt.tight_layout()
# plt.savefig(FIGS / 'correlaciones.png', dpi=150)
# plt.show()
pass

# %% [markdown]
# ## 3. Distribución de variables clave

# %%
# cols = ['precip_7d_mm', 'pendiente_promedio', 'n_events_30d', 'humedad_suelo_pct']
# fig, axes = plt.subplots(2, 2, figsize=(12, 8))
# for ax, col in zip(axes.flatten(), cols):
#     df[col].hist(ax=ax, bins=40, color='#8B6914')
#     ax.set_title(col)
# plt.tight_layout()
# plt.savefig(FIGS / 'distribuciones.png', dpi=150)
# plt.show()
pass

# %% [markdown]
# ## 4. Desbalance de clases

# %%
# target_counts = df['target'].value_counts()
# print(f'Clase 0 (sin evento): {target_counts[0]:,}')
# print(f'Clase 1 (deslizamiento): {target_counts[1]:,}')
# print(f'Ratio de desbalance: {target_counts[0]/target_counts[1]:.0f}:1')
pass

# %% [markdown]
# ## 5. Serie temporal de riesgo por comunas de alta criticidad

# %%
# comunas_criticas = ['13', '7', '3']  # San Javier, Robledo, Santa Cruz
# fig, ax = plt.subplots(figsize=(14, 5))
# for cid in comunas_criticas:
#     sub = df[df['commune_id'] == cid].sort_values('feature_date')
#     ax.plot(sub['feature_date'], sub['precip_7d_mm'], label=f'Comuna {cid}')
# ax.legend()
# ax.set_title('Precipitación acumulada 7d — comunas críticas')
# plt.tight_layout()
# plt.show()
pass
