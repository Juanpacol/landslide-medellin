# %% [markdown]
# # 05 — Reportes Automáticos
#
# **Objetivo:** Generar reportes ejecutivos, gráficos dinámicos y el PDF de resultados de forma automatizada.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import json
from pathlib import Path
from datetime import datetime

PROC   = Path('../data/processed')
MODELS = Path('../models/predictive')
FIGS   = Path('../reports/figures')
REPORT = Path('../reports')

# %% [markdown]
# ## 1. Cargar métricas del modelo

# %%
# with open(MODELS / 'metrics.json') as f:
#     metrics = json.load(f)
# print(f"AUC-ROC: {metrics['auc_roc']}")
# print(f"Recall:  {metrics['recall']}")
# print(f"Entrenado: {metrics['trained_at']}")
pass

# %% [markdown]
# ## 2. Reporte de estado por comunas (Top riesgo)

# %%
# Conectar a BD para datos en vivo, o leer predictions.csv exportado
# df_pred = pd.read_csv(PROC / 'risk_predictions_latest.csv')
# top5 = df_pred.nlargest(5, 'risk_score')[['nombre','risk_score','risk_category']]
# print('Top 5 comunas en mayor riesgo:')
# print(top5.to_string(index=False))
pass

# %% [markdown]
# ## 3. Gráfico de barras — Riesgo por comuna

# %%
# color_map = {'bajo':'#52a55c','medio':'#c8a63f','alto':'#c27a30','critico':'#b84a3a'}
# fig, ax = plt.subplots(figsize=(14, 6))
# bars = ax.bar(
#     df_pred['nombre'],
#     df_pred['risk_score'],
#     color=[color_map[c] for c in df_pred['risk_category']]
# )
# ax.axhline(0.65, color='orange', linestyle='--', label='Umbral alto')
# ax.axhline(0.90, color='red', linestyle='--', label='Umbral crítico')
# ax.set_title(f'Nivel de riesgo por comuna — {datetime.now().strftime("%Y-%m-%d %H:%M")}')
# ax.set_ylabel('Risk Score')
# plt.xticks(rotation=45, ha='right')
# ax.legend()
# plt.tight_layout()
# plt.savefig(FIGS / 'riesgo_comunas.png', dpi=150)
# plt.show()
pass

# %% [markdown]
# ## 4. Sparklines de precipitación 7 días

# %%
pass

# %% [markdown]
# ## 5. Exportar reporte PDF

# %%
# Ejecutar desde terminal:
# jupyter nbconvert --to pdf notebooks/05_reportes_automaticos.ipynb --output reports/reporte_final.pdf
print('Ejecutar: jupyter nbconvert --to pdf notebooks/05_reportes_automaticos.ipynb --output reports/reporte_final.pdf')
